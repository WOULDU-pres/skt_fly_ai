# %% [markdown]
# # Seaborn

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
sns.__version__
# Out:
# '0.12.1'

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df.groupby(['island','species','sex'])['flipper_length_mm'].value_counts()
# Out:
# island     species  sex     flipper_length_mm
# Biscoe     Adelie   Female  187.0                3
#                             181.0                2
#                             185.0                2
#                             186.0                2
#                             193.0                2
#                                                 ..
# Torgersen  Adelie   Male    193.0                1
#                             194.0                1
#                             196.0                1
#                             202.0                1
#                             210.0                1
# Name: flipper_length_mm, Length: 163, dtype: int64

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %% [markdown]
# ### Axis Level

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(data=df, x='flipper_length_mm', y='bill_length_mm', hue='species')
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.histplot(data=df, x='species', hue='species')
# Out:
# <AxesSubplot: xlabel='species', ylabel='Count'>

# %%
fig, axes = plt.subplots(2,2, figsize=(10,5))
sns.scatterplot(data=df, x='flipper_length_mm', y='bill_length_mm', hue='species', ax=axes[0,0])
sns.histplot(data=df, x='species', hue='species', ax=axes[1,0])
sns.scatterplot(data=df, x='flipper_length_mm', y='bill_length_mm', hue='species', ax=axes[0,1])
sns.histplot(data=df, x='species', hue='species', ax=axes[1,1])
# Out:
# <AxesSubplot: xlabel='species', ylabel='Count'>

# %% [markdown]
# ### figure level

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.displot(data=df, 
            x='flipper_length_mm', 
            kind='hist', 
            hue='species',
            col='species')

# %%
sns.displot(data=df, 
            x='flipper_length_mm', 
            kind='kde', 
            hue='species',
            col='species')

# %%
sns.displot(data=df, 
            x='flipper_length_mm', 
            kind='ecdf', 
            hue='species',
            col='species')

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.relplot(data=df, 
            x='flipper_length_mm',
            y='bill_length_mm', 
            hue ='species',
            col='species',
            height=5,
            aspect=1)

# %%
df = pd.read_csv('titanic.csv')
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1     lost    3rd
# 1            2    saved    1st
# 2            3    saved    3rd
# 3            4    saved    1st
# 4            5     lost    3rd
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(data=df, x='Pclass', y= 'Fare')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Fare'>

# %%
sns.countplot(data=df, x='Pclass')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts()
# Out:
# 3rd    491
# 1st    216
# 2nd    184
# Name: Pclass, dtype: int64

# %%
sns.barplot(data=df, x='Pclass', y= 'Fare', hue='Sex', estimator = np.mean)
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(data=df, x='Pclass', y='Age')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Age'>

# %%
sns.violinplot(data=df, x='Pclass', y='Age')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Age'>

# %%
data = np.random.rand(3,3)
data
# Out:
# array([[0.98672471, 0.02979669, 0.62781102],
#        [0.76794696, 0.77084578, 0.54001174],
#        [0.89759653, 0.53527476, 0.1037656 ]])

# %%
sns.heatmap(data, annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot: >

# %%
df = pd.read_csv('iris.csv', index_col=0)
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="Species")

# %%
# !gdown https://raw.githubusercontent.com/devdio/datasets/main/tips.csv

# %%
df = pd.read_csv('tips.csv')
df.shape
# Out:
# (244, 7)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
