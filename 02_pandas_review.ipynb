# %% [markdown]
# # 판다스
# ---

# %%
import pandas as pd
import numpy as np

pd.__version__
# Out:
# '1.5.2'

# %% [markdown]
# ## Series

# %%
sr = pd.Series([1,2,3,4,5,np.nan],
               name = 'Apple',
               index = ['a','d','q','w','e','f'])
sr
# Out:
# a    1.0
# d    2.0
# q    3.0
# w    4.0
# e    5.0
# f    NaN
# Name: Apple, dtype: float64

# %%
sr.values
# Out:
# array([ 1.,  2.,  3.,  4.,  5., nan])

# %%
sr.reset_index()
# Out:
#   index  Apple
# 0     a    1.0
# 1     d    2.0
# 2     q    3.0
# 3     w    4.0
# 4     e    5.0
# 5     f    NaN

# %%
#fancy indexing
sr[[1,2,3]].reset_index()
# Out:
#   index  Apple
# 0     d    2.0
# 1     q    3.0
# 2     w    4.0

# %%
#boolean indexing

# %%
sr[sr>2]
# Out:
# q    3.0
# w    4.0
# e    5.0
# Name: Apple, dtype: float64

# %%
sr.isna()
# Out:
# a    False
# d    False
# q    False
# w    False
# e    False
# f     True
# Name: Apple, dtype: bool

# %%
sr[sr.isna()]
# Out:
# f   NaN
# Name: Apple, dtype: float64

# %%
sr.isna().sum()
# Out:
# 1

# %%
x = sr.copy()

# %%
x[x.isna()] = x.mean()
x
# Out:
# a    1.0
# d    2.0
# q    3.0
# w    4.0
# e    5.0
# f    3.0
# Name: Apple, dtype: float64

# %%
w = sr.copy()

# %%
w.fillna(sr.mean())
# Out:
# a    1.0
# d    2.0
# q    3.0
# w    4.0
# e    5.0
# f    3.0
# Name: Apple, dtype: float64

# %%
sr.dropna()
# Out:
# a    1.0
# d    2.0
# q    3.0
# w    4.0
# e    5.0
# Name: Apple, dtype: float64

# %%
x = x.dropna()
w.dropna(inplace=True)

# %% [markdown]
# ## 슬라이싱

# %%
sr = pd.Series([13,23,32,13,24],
               index = ['john','eva','sie','df','dfa'])
sr
# Out:
# john    13
# eva     23
# sie     32
# df      13
# dfa     24
# dtype: int64

# %%
sr[1:]
# Out:
# eva    23
# sie    32
# df     13
# dfa    24
# dtype: int64

# %%
sr['john':'dfa']
# Out:
# john    13
# eva     23
# sie     32
# df      13
# dfa     24
# dtype: int64

# %%
sr.sort_values()
# Out:
# john    13
# df      13
# eva     23
# dfa     24
# sie     32
# dtype: int64

# %%
sr.sort_values(ascending=False)
# Out:
# sie     32
# dfa     24
# eva     23
# john    13
# df      13
# dtype: int64

# %%
sr.sort_index()
# Out:
# df      13
# dfa     24
# eva     23
# john    13
# sie     32
# dtype: int64

# %%
doc = [['Joe', 20, 85.10, 'A', 'Swimming'],
        ['Nat', 21, 77.80, 'B', 'Reading'],
        ['Harry', 19, 91.54, 'A', 'Music'],
        ['Sam', 20, 88.78, 'A', 'Painting'],
        ['Monica', 22, 60.55, 'B', 'Dancing']]

c_name = ['Name', 'Age', 'Marks', 'Grade', 'Hobby']
idx = ['s1', 's2', 's3', 's4', 's5']

# %%
df = pd.DataFrame(doc, columns = c_name, index = idx)
df.shape
df
# Out:
#       Name  Age  Marks Grade     Hobby
# s1     Joe   20  85.10     A  Swimming
# s2     Nat   21  77.80     B   Reading
# s3   Harry   19  91.54     A     Music
# s4     Sam   20  88.78     A  Painting
# s5  Monica   22  60.55     B   Dancing

# %%
df[df.columns[2]]
# Out:
# s1    85.10
# s2    77.80
# s3    91.54
# s4    88.78
# s5    60.55
# Name: Marks, dtype: float64

# %%
df.dtypes
# Out:
# Name      object
# Age        int64
# Marks    float64
# Grade     object
# Hobby     object
# dtype: object

# %%
df.columns[[0,3,4]]
# Out:
# Index(['Name', 'Grade', 'Hobby'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, s1 to s5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Marks   5 non-null      float64
#  3   Grade   5 non-null      object
#  4   Hobby   5 non-null      object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 412.0+ bytes

# %%
titanic = pd.read_csv('titanic.csv')
titanic.shape
# Out:
# (891, 12)

# %%
df = titanic.copy()
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_columns = [i.lower() for i in df.columns]

# %%
df.columns = df_columns
df
# Out:
#      passengerid survived pclass  \
# 0              1     lost    3rd
# 1              2    saved    1st
# 2              3    saved    3rd
# 3              4    saved    1st
# 4              5     lost    3rd
# ..           ...      ...    ...
# 886          887     lost    2nd
# 887          888    saved    1st
# 888          889     lost    3rd
# 889          890    saved    1st
# 890          891     lost    3rd
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    object
#  2   pclass       891 non-null    object
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        204 non-null    object
#  11  embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        passengerid         age       sibsp       parch        fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head()
# Out:
#    passengerid survived pclass  \
# 0            1     lost    3rd
# 1            2    saved    1st
# 2            3    saved    3rd
# 3            4    saved    1st
# 4            5     lost    3rd
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
df['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df[df.columns[[3,4]]].value_counts()
# Out:
# name                                     sex
# Abbing, Mr. Anthony                      male      1
# Nysveen, Mr. Johan Hansen                male      1
# Nicholson, Mr. Arthur Ernest             male      1
# Nicola-Yarred, Master. Elias             male      1
# Nicola-Yarred, Miss. Jamila              female    1
#                                                   ..
# Goodwin, Miss. Lillian Amy               female    1
# Goodwin, Mr. Charles Edward              male      1
# Goodwin, Mrs. Frederick (Augusta Tyler)  female    1
# Graham, Miss. Margaret Edith             female    1
# van Melkebeke, Mr. Philemon              male      1
# Length: 891, dtype: int64

# %%
df.loc[5:10, ['pclass']] # 세로축 가로축
# Out:
#    pclass
# 5     3rd
# 6     1st
# 7     3rd
# 8     3rd
# 9     2nd
# 10    3rd

# %%
df.isna()
# Out:
#      passengerid  survived  pclass   name    sex    age  sibsp  parch  ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       fare  cabin  embarked
# ...

# %%
df['age'].min()
# Out:
# 0.42

# %%
df.loc[df['age'].isna()]
# Out:
#      passengerid survived pclass                                      name  \
# 5              6     lost    3rd                          Moran, Mr. James
# 17            18    saved    2nd              Williams, Mr. Charles Eugene
# 19            20    saved    3rd                   Masselmani, Mrs. Fatima
# 26            27     lost    3rd                   Emir, Mr. Farred Chehab
# 28            29    saved    3rd             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...      ...    ...                                       ...
# 859          860     lost    3rd                          Razi, Mr. Raihed
# 863          864     lost    3rd         Sage, Miss. Dorothy Edith "Dolly"
# 868          869     lost    3rd               van Melkebeke, Mr. Philemon
# 878          879     lost    3rd                        Laleff, Mr. Kristo
# 888          889     lost    3rd  Johnston, Miss. Catherine Helen "Carrie"
#
#         sex  age  sibsp  parch      ticket     fare cabin embarked
# ...

# %%
df[0:1]
# Out:
#    passengerid survived pclass                     name   sex   age  sibsp  \
# 0            1     lost    3rd  Braund, Mr. Owen Harris  male  22.0      1
#
#    parch     ticket  fare cabin embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df.loc[df['age'].isna(),['sex']].value_counts()
# Out:
# sex
# male      124
# female     53
# dtype: int64

# %%
df['embarked'] = df['embarked'].fillna('S')

# %%
df.isna().sum(axis = 0)
# Out:
# passengerid      0
# survived         0
# pclass           0
# name             0
# sex              0
# age            177
# sibsp            0
# parch            0
# ticket           0
# fare             0
# cabin          687
# embarked         0
# dtype: int64

# %%
df['cabin'] = df['cabin'].fillna('B28')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    object
#  2   pclass       891 non-null    object
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        891 non-null    object
#  11  embarked     891 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
df.drop(["cabin","ticket"], axis=1)
# Out:
#      passengerid survived pclass  \
# 0              1     lost    3rd
# 1              2    saved    1st
# 2              3    saved    3rd
# 3              4    saved    1st
# 4              5     lost    3rd
# ..           ...      ...    ...
# 886          887     lost    2nd
# 887          888    saved    1st
# 888          889     lost    3rd
# 889          890    saved    1st
# 890          891     lost    3rd
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
## 결측치 fillna, isna 등

# %%
df
# Out:
#      passengerid survived pclass  \
# 0              1     lost    3rd
# 1              2    saved    1st
# 2              3    saved    3rd
# 3              4    saved    1st
# 4              5     lost    3rd
# ..           ...      ...    ...
# 886          887     lost    2nd
# 887          888    saved    1st
# 888          889     lost    3rd
# 889          890    saved    1st
# 890          891     lost    3rd
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['family'] = df['sibsp'] + df['parch']

# %%
df
# Out:
#      passengerid survived pclass  \
# 0              1     lost    3rd
# 1              2    saved    1st
# 2              3    saved    3rd
# 3              4    saved    1st
# 4              5     lost    3rd
# ..           ...      ...    ...
# 886          887     lost    2nd
# 887          888    saved    1st
# 888          889     lost    3rd
# 889          890    saved    1st
# 890          891     lost    3rd
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['family'] = np.nan
df
# Out:
#      passengerid survived pclass  \
# 0              1     lost    3rd
# 1              2    saved    1st
# 2              3    saved    3rd
# 3              4    saved    1st
# 4              5     lost    3rd
# ..           ...      ...    ...
# 886          887     lost    2nd
# 887          888    saved    1st
# 888          889     lost    3rd
# 889          890    saved    1st
# 890          891     lost    3rd
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['age'].median()
# Out:
# 28.0

# %%
df['age'].mean()
# Out:
# 29.69911764705882

# %%
df['age'].fillna(df['age'].median(), inplace = True)
df
# Out:
#      passengerid survived pclass  \
# 0              1     lost    3rd
# 1              2    saved    1st
# 2              3    saved    3rd
# 3              4    saved    1st
# 4              5     lost    3rd
# ..           ...      ...    ...
# 886          887     lost    2nd
# 887          888    saved    1st
# 888          889     lost    3rd
# 889          890    saved    1st
# 890          891     lost    3rd
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby('sex').value_counts()
# Out:
# Series([], dtype: int64)
